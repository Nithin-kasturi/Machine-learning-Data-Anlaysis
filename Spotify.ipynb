# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('tracks.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
pd.isnull(df).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
sorted_df=df.sort_values('popularity',ascending=False)

# %%
sorted_df.head(10)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
# 92819  1xK1Gg9SxG8fy2Ya373oqb                                 Bandido
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %%
most_popular=df.query('popularity>90',inplace=False).sort_values('popularity',ascending=True)

# %%
most_popular
# Out:
#                            id  \
# 92835  6Im9k8u9iIzKMrmV7BWtlF
# 93814  5YaskwnGDZFDRipaqzbwQx
# 93813  2TksvaRivgAEj780DgRB73
# 92841  1tkg4EHVoqnhR6iFEXb60y
# 92839  6cx06DFPPHchuUAcTxznu9
# 92837  7ytR5pFWmSjzHJIeQkgog4
# 93815  3aQem4jVGdhtg116TmJnHz
# 92833  7vrJn5hDSXRmdXoR30KgF1
# 92832  45bE4HXI0AwGZXfZtMp8JR
# 92830  4saklk6nie3yiGePpBwUoc
# 93816  1diS6nkxMQc3wwC4G1j0bh
# 92824  47EiUVwUp4C9fGccaPuUCS
# 92826  35mvY5S1H3J2QZyna3TFe0
# 92827  3VvA1wSxukMLsvXoXtlwWx
# 92829  6ft4hAq6yde8jPZY2i5zLr
# 91867  6UelLqGlWMcVH1E5c4H7lY
# 93812  3iw6V4LH7yPj1ESORX9RIN
# 93811  4u4NyuceXP7Uzh7XFJKCr1
# 93810  5uEYRdEIh9Bo4fpjDd4Na9
# 93809  1XXimziG1uhM0eDNCZCrUl
# 93808  5YYW3yRktprLRr47WK219Y
# 92821  2XIc1pqjXV3Cr2BQUGNBck
# 92823  3YJJjQPAbDT7mGpX3WtQ9A
# 93807  4cG7HUWYHBV6R6tHn1gxrl
# 93806  7Bk0uXKk1uPT0XuQbpFzvs
# 91866  60ynsPSSKe6O3sfwRnIBRf
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp
# 92817  27OeeYzk6klgBh83TSvGMA
# 92819  1xK1Gg9SxG8fy2Ya373oqb
# 92814  6f3Slt0GbA2bPZlz0aIFXN
# ...

# %%
df.set_index('release_date',inplace=True)

# %%
df.index=pd.to_datetime(df.index)

# %%
df
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                              ...                                  ...
# 2020-09-26    5rgu12WBIHQtvej2MdHSH0                                  云与海
# 2020-10-21    0NuWgxEp51CutD2pJoF4OM                                blind
# 2020-09-02    27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 2021-03-05    45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 2015-07-01    5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#               popularity  duration_ms  explicit  \
# release_date
# ...

# %%
df.rename(columns={'duration_ms':'Duration'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 586672 entries, 1922-02-22 to 2015-07-01
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   Duration          586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   danceability      586672 non-null  float64
#  8   energy            586672 non-null  float64
#  9   key               586672 non-null  int64
#  10  loudness          586672 non-null  float64
#  11  mode              586672 non-null  int64
#  12  speechiness       586672 non-null  float64
#  13  acousticness      586672 non-null  float64
#  14  instrumentalness  586672 non-null  float64
# ...

# %%
df['Duration']=df['Duration'].apply(lambda x:round(x/1000))

# %%
df["Duration"]
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-01-01    163
#              ...
# 2020-09-26    258
# 2020-10-21    153
# 2020-09-02    188
# 2021-03-05    142
# 2015-07-01    214
# Name: Duration, Length: 586672, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 586672 entries, 1922-02-22 to 2015-07-01
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   Duration          586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   danceability      586672 non-null  float64
#  8   energy            586672 non-null  float64
#  9   key               586672 non-null  int64
#  10  loudness          586672 non-null  float64
#  11  mode              586672 non-null  int64
#  12  speechiness       586672 non-null  float64
#  13  acousticness      586672 non-null  float64
#  14  instrumentalness  586672 non-null  float64
# ...

# %%
correlation=df.drop(['explicit','key','mode'],axis=1).corr(method='pearson')
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_7088\2508450460.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.drop(['explicit','key','mode'],axis=1).corr(method='pearson')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,6))
heatmap=sns.heatmap(correlation,annot=True,vmin=-1,vmax=1)

# %%
sample_df=df.sample(int(0.004*len(df)))

# %%
print(len(sample_df))
# Out:
# 2346

# %%
sns.regplot(data=sample_df,x='energy',y='loudness',color='c')
plt.figure(figsize=(14,6))

# %%
sns.regplot(data=sample_df,y='popularity',x='acousticness',color='b')
# Out:
# <Axes: xlabel='acousticness', ylabel='popularity'>

# %%
pip install --user seaborn==0.11.0
# Out:
# ...
#      ---------------------------------------- 0.0/283.1 kB ? eta -:--:--
#      ---- ---------------------------------- 30.7/283.1 kB 1.4 MB/s eta 0:00:01
#      -------- ---------------------------- 61.4/283.1 kB 825.8 kB/s eta 0:00:01
#      -------- ---------------------------- 61.4/283.1 kB 825.8 kB/s eta 0:00:01
#      -------- ---------------------------- 61.4/283.1 kB 825.8 kB/s eta 0:00:01
#      ------------ ------------------------ 92.2/283.1 kB 438.1 kB/s eta 0:00:01
#      -------------- --------------------- 112.6/283.1 kB 409.6 kB/s eta 0:00:01
#      --------------- -------------------- 122.9/283.1 kB 380.5 kB/s eta 0:00:01
#      ------------------ ----------------- 143.4/283.1 kB 355.0 kB/s eta 0:00:01
#      -------------------- --------------- 163.8/283.1 kB 364.8 kB/s eta 0:00:01
#      -------------------------- --------- 204.8/283.1 kB 429.5 kB/s eta 0:00:01
#      -------------------------- --------- 204.8/283.1 kB 429.5 kB/s eta 0:00:01
# ...

# %%
df['year']=pd.DatetimeIndex(df.index).year

# %%
sns.displot(data=df['year'],discrete=True,aspect=2,height=5,kind='hist').set(title="Number of songs per year")

# %%
total_dr=df.Duration
fig_dims=(18,7)
fig,ax=plt.subplots(figsize=fig_dims)
fig=sns.barplot(x=df['years'],y=total_dr,ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[104], line 4
#       2 fig_dims=(18,7)
#       3 fig,ax=plt.subplots(figsize=fig_dims)
# ----> 4 fig=sns.barplot(x=df['years'],y=total_dr,ax=ax)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# ...
